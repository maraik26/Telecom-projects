# %%
import re

import nltk
import pymorphy2
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer


from natasha import LocationExtractor

# %%
nltk.download('stopwords')
nltk.download('punkt')

stopword_ru = []

stopword_ru = stopwords.words('russian')
stopword_ru += stopwords.words('english')
stopword_ru.append('м')
stopword_ru.append('это')
stopword_ru.append('ru')
stopword_ru.append('com')
stopword_ru.append('net')
stopword_ru.append('www')
stopword_ru.append('заголовок')
stopword_ru.append('пустой')
stopword_ru.append('главный')
stopword_ru.append('магазин')
stopword_ru.append('интернет')
stopword_ru.append('сайт')
stopword_ru.append('сайтов')
stopword_ru.append('купить')
stopword_ru.append('страница')
stopword_ru.append('онлайн')
stopword_ru.append('веб')
stopword_ru.append('ваш')
stopword_ru.append('ру')
stopword_ru.append('главный')
stopword_ru.append('класс')
stopword_ru.append('люкс')
stopword_ru.append('премиум')
stopword_ru.append('санкт')
stopword_ru.append('официальный')
stopword_ru.append('портал')
stopword_ru.append('салон')
stopword_ru.append('скидка')
stopword_ru.append('скачать')
stopword_ru.append('компания')
stopword_ru.append('клуб')
stopword_ru.append('доставка')
stopword_ru.append('центр')
stopword_ru.append('государственный')
stopword_ru.append('ооо')
stopword_ru.append('товар')
stopword_ru.append('hd')
stopword_ru.append('самый')
stopword_ru.append('продажа')
stopword_ru.append('новости')
stopword_ru.append('услуга')
stopword_ru.append('акция')
stopword_ru.append('система')
stopword_ru.append('регистрация')
stopword_ru.append('добро')
stopword_ru.append('пожаловать')
stopword_ru.append('сеть')
stopword_ru.append('метро')
stopword_ru.append('цена')
stopword_ru.append('бесплатный')
stopword_ru.append('бесплатно')
stopword_ru.append('средство')
stopword_ru.append('хороший')
stopword_ru.append('мир')
stopword_ru.append('выбор')
stopword_ru.append('pro')
stopword_ru.append('спб')
stopword_ru.append('весь')
stopword_ru.append('заказ')

names_and_cities = [x[:-1].lower() for x in list(open("Names_and_cities.txt","r"))]

morph = pymorphy2.MorphAnalyzer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mbabaeva\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mbabaeva\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
cache = {}
expired = {'domain', 'expired'}

extractor_loc = LocationExtractor()

def clean_text(text):
    '''
        очистка текста от мусора
    '''
    text = re.sub(r'18\+', 'порно', text)
    text = re.sub('-\s\r\n\|-\s\r\n|\r\n|[«»]|[""]|[><]"[\[]]|//"', '', str(text))
    text = re.sub('[«»]|[""]|[><]"[\[]]"', '', text)
    text = re.sub('[0-9]|[-.,:;_%©?*!@#№$^•·&()]|[+=]|[[]|[]]|[/]|"|–|—|', ' ', text)
    text = re.sub(r'\r\n\t|\n|\\s|\r\t|\\n', ' ', text)
    text = re.sub(r'[\xad]|[\s+]', ' ', text)
    text = re.sub('ё', 'е', text.strip().lower())
    
    '''
        очистка текста от названий городов
    '''  
    """
    for match in reversed(extractor_loc(text)):
        start, stop = match.span
        text = text.replace(text[start:stop], '')
"""
    return text

def token_stop_pymorph(text):
    '''
        [0] токенизация предложения
        [1] проверка есть ли в начале слова '-'
        [2] проверка на стоп-слова
        [3] проверка есть ли данное слово в кэше
        [4] лемматизация слова
    на выходе лист токенов
    '''

    if not isinstance(text, str):
        text = str(text)
    if text.find('domain has expired') != -1:
        return 0
    words = word_tokenize(text)
    
    words_lem = []
    for w in words:
        if w[0] == '-':
            w = w[1:]
        if len(w) == 1:
            continue
        if w in expired:
            continue
        w = morph.parse(w)[0].normal_form
        if (w not in stopword_ru) and (w not in names_and_cities):
            if w in cache:
                words_lem.append(cache[w])
            else:
                temp_cach = cache[w] = w
                words_lem.append(temp_cach)
    
    return words_lem

# %%
data = pd.read_csv('sites.csv')
data = data.loc[pd.notnull(data.url) & pd.notnull(data.text)].reset_index(drop=True)
data = data.loc[(data.text.apply(len) > 15) & (data.text.apply(len) < 150)].reset_index(drop=True)

# %%
data.head(10)
# Out:
#                       url                                               text
# 0     http://forma1998.ru  Сеть магазинов Форма 1998 - сувениры и подарки...
# 1    http://azumihair.com            Cредство для восстановления волос AZUMI
# 2      http://lamiland.ru  ЛамиЛэнд - интересный магазин напольных покрытий.
# 3         http://glira.ru  Купить септик Топас в Москве - от официального...
# 4  http://money2mobile.ru  Пополнение телефона или электронного кошелька ...
# 5         http://jandi.ru                        jandi.ru domain has expired
# 6        http://rgtvi.ru/                 Информационно развлекательный Сайт
# 7      http://mamatov.com      Клуб здоровья и долголетия Алексея Маматова |
# 8   http://tyuningavto.ru  Перетяжка салона автомобиля в ателье- АвтоКомфорт
# 9   http://delta-parts.ru       Интернет каталог аксессуаров для автомобилей

# %%
hostings = ['Домен не прилинкован ни к одной из директорий на сервере!',
            'Этот домен припаркован компанией Timeweb',
            'Данный веб-сайт выставлен на продажу!',
            'masterhost - профессиональный хостинг сайта',
            'Интернет Хостинг Центра']

for hosting in hostings:
    data = data[data['text'].apply(lambda x: True if hosting not in x else False)]

# %%
# %time

text = [clean_text(s) for s in data.text.tolist()]
text = [token_stop_pymorph(s) for s in text]
# Out:
# Wall time: 0 ns
# C:\Users\mbabaeva\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: Possible nested set at position 36
#   del sys.path[0]

# %%
data = list((txt, url, raw_text) for txt, url, raw_text 
            in zip(text, data.url.tolist(), data.text.tolist()) if txt != 0)

# %%
data[:2]
# Out:
# [(['форма', 'сувенир', 'подарок', 'особый', 'назначение'],
#   'http://forma1998.ru',
#   'Сеть магазинов Форма 1998 - сувениры и подарки особого назначения'),
#  (['cредство', 'восстановление', 'волос', 'azumi'],
#   'http://azumihair.com',
#   'Cредство для восстановления волос AZUMI')]

# %%
len(data)
# Out:
# 231682

# %%
new_data = pd.DataFrame()

text, url, raw_text = zip(*data)
new_data['raw_text'] = raw_text
new_data['text'] = text
new_data['url'] = url

# %%
new_data.head(15)
# Out:
#                                              raw_text  \
# 0   Сеть магазинов Форма 1998 - сувениры и подарки...
# 1             Cредство для восстановления волос AZUMI
# 2   ЛамиЛэнд - интересный магазин напольных покрытий.
# 3   Купить септик Топас в Москве - от официального...
# 4   Пополнение телефона или электронного кошелька ...
# 5                  Информационно развлекательный Сайт
# 6       Клуб здоровья и долголетия Алексея Маматова |
# 7   Перетяжка салона автомобиля в ателье- АвтоКомфорт
# 8        Интернет каталог аксессуаров для автомобилей
# 9   Фитолампы для растений магазин в СПб, фитоламп...
# 10  продажа автозапчастей - автозапчасти из Японии...
# 11   К миру по нитке. Статьи о разумной жизни в мире.
# 12           Валентина Толкунова: творчество и судьба
# 13  Купить термос, термокружку, ланчбокс и термосу...
# 14  binogi.ru - Всё о ногах, болезнях ног и их леч...
#
#                                                  text                     url
# 0       [форма, сувенир, подарок, особый, назначение]     http://forma1998.ru
# 1            [cредство, восстановление, волос, azumi]    http://azumihair.com
# 2         [ламилэнд, интересный, напольный, покрытие]      http://lamiland.ru
# 3               [септик, топас, дилер, производитель]         http://glira.ru
# 4   [пополнение, телефон, электронный, кошелёк, ск...  http://money2mobile.ru
# 5                    [информационно, развлекательный]        http://rgtvi.ru/
# 6                   [здоровье, долголетие, маматовый]      http://mamatov.com
# 7        [перетяжка, автомобиль, ателье, автокомфорт]   http://tyuningavto.ru
# 8                    [каталог, аксессуар, автомобиль]   http://delta-parts.ru
# 9    [фитолампа, растение, фитолампа, фитосветильник]      http://letsgrow.ru
# 10        [автозапчасть, автозапчасть, япония, корея]       http://filtok2.ru
# 11                   [нитка, статья, разумный, жизнь]  http://cmiruponitke.ru
# 12                   [толкуновый, творчество, судьба]   http://vtolkunova.com
# 13  [термос, термокружка, ланчбокс, термосумка, ро...  http://kupit-termos.ru
# 14             [binogi, нога, болезнь, нога, лечение]        http://binogi.ru

# %%
new_data = new_data.loc[new_data.text.apply(len) >= 4].reset_index(drop=True)

# %%
new_data.head(15)
# Out:
#                                              raw_text  \
# 0   Сеть магазинов Форма 1998 - сувениры и подарки...
# 1             Cредство для восстановления волос AZUMI
# 2   ЛамиЛэнд - интересный магазин напольных покрытий.
# 3   Купить септик Топас в Москве - от официального...
# 4   Пополнение телефона или электронного кошелька ...
# 5   Перетяжка салона автомобиля в ателье- АвтоКомфорт
# 6   Фитолампы для растений магазин в СПб, фитоламп...
# 7   продажа автозапчастей - автозапчасти из Японии...
# 8    К миру по нитке. Статьи о разумной жизни в мире.
# 9   Купить термос, термокружку, ланчбокс и термосу...
# 10  binogi.ru - Всё о ногах, болезнях ног и их леч...
# 11  Дизайн интерьера, дизайн квартир, дома, курсы ...
# 12  Доставка пиццы и роллов в Коломне. Заказать су...
# 13  Купить дешево Леджинсы Slim Jeggings с кармана...
# 14  Скачать фильмы, музыку, игры через торрент на ...
#
#                                                  text                     url
# 0       [форма, сувенир, подарок, особый, назначение]     http://forma1998.ru
# 1            [cредство, восстановление, волос, azumi]    http://azumihair.com
# 2         [ламилэнд, интересный, напольный, покрытие]      http://lamiland.ru
# 3               [септик, топас, дилер, производитель]         http://glira.ru
# 4   [пополнение, телефон, электронный, кошелёк, ск...  http://money2mobile.ru
# 5        [перетяжка, автомобиль, ателье, автокомфорт]   http://tyuningavto.ru
# 6    [фитолампа, растение, фитолампа, фитосветильник]      http://letsgrow.ru
# 7         [автозапчасть, автозапчасть, япония, корея]       http://filtok2.ru
# 8                    [нитка, статья, разумный, жизнь]  http://cmiruponitke.ru
# 9   [термос, термокружка, ланчбокс, термосумка, ро...  http://kupit-termos.ru
# 10             [binogi, нога, болезнь, нога, лечение]        http://binogi.ru
# 11  [дизайн, интерьер, дизайн, квартира, дом, курс...       http://artburo.su
# 12  [пицца, ролл, заказать, суши, заказать, пицца,...  http://center-sushi.ru
# 13  [дёшево, леджинса, slim, jeggings, карман, ком...     http://top-veshi.ru
# 14        [фильм, музыка, торрент, высокий, скорость]      http://torrentk.ru

# %%
text = new_data.text.tolist()

# %%
from gensim.corpora import Dictionary
from gensim.models import TfidfModel

corp_dct = Dictionary(text, prune_at=15000) # fit dictionary, initialize a Dictionary
print(corp_dct)
# Out:
# Dictionary(21352 unique tokens: ['назначение', 'особый', 'подарок', 'сувенир', 'форма']...)

# %%
corp_dct.filter_n_most_frequent(1000) #Filter out the ‘remove_n’ most frequent tokens that appear in the documents.
print(corp_dct)
# Out:
# Dictionary(20352 unique tokens: ['назначение', 'особый', 'cредство', 'восстановление', 'септик']...)

# %%
corpus = [corp_dct.doc2bow(line) for line in text] # convert corpus to BoW format, mapping between words and their integer ids

# %%
len(corpus)
# Out:
# 148328

# %%
#TF-IDF scheme is used for extracting features or important words which can be the best representative of your document. 
tfidf_model = TfidfModel(corpus, id2word=corp_dct) #http://www.tfidf.com/, # fit model
corpus = tfidf_model[corpus] #apply model to the corpus document

# %%
corpus

# %%
print('--here!--')
# Out:
# --here!--

# %%
flattened_corpus = [[word[1] for word in record] for record in corpus.corpus]

# %%
corpus = list()
for t, c, u, rt in zip(new_data.text.tolist(), flattened_corpus, 
                       new_data.url.tolist(), new_data.raw_text.tolist()):
    if len(c) > 0:
        corpus.append((rt, list(zip(t, c)), u))
        continue

# %%
for i, j in enumerate(corpus):
    print(i, j)
    if i > 15:
        break
# Out:
# 0 ('Сеть магазинов Форма 1998 - сувениры и подарки особого назначения', [('форма', 1), ('сувенир', 1), ('подарок', 1), ('особый', 1), ('назначение', 1)], 'http://forma1998.ru')
# 1 ('Cредство для восстановления волос AZUMI', [('cредство', 1), ('восстановление', 1), ('волос', 1)], 'http://azumihair.com')
# 2 ('ЛамиЛэнд - интересный магазин напольных покрытий.', [('ламилэнд', 1), ('интересный', 1), ('напольный', 1)], 'http://lamiland.ru')
# 3 ('Купить септик Топас в Москве - от официального дилера производителя', [('септик', 1), ('топас', 1), ('дилер', 1), ('производитель', 1)], 'http://glira.ru')
# 4 ('Пополнение телефона или электронного кошелька через скретч-карты', [('пополнение', 1), ('телефон', 1), ('электронный', 1), ('кошелёк', 1), ('скретч', 1), ('карта', 1)], 'http://money2mobile.ru')
# 5 ('Перетяжка салона автомобиля в ателье- АвтоКомфорт', [('перетяжка', 1), ('автомобиль', 1), ('ателье', 1), ('автокомфорт', 1)], 'http://tyuningavto.ru')
# 6 ('Фитолампы для растений магазин в СПб, фитолампы и фитосветильники!', [('фитолампа', 1), ('растение', 2), ('фитолампа', 1)], 'http://letsgrow.ru')
# 7 ('продажа автозапчастей - автозапчасти из Японии и Кореи', [('автозапчасть', 2), ('автозапчасть', 1), ('япония', 1)], 'http://filtok2.ru')
# 8 ('К миру по нитке. Статьи о разумной жизни в мире.', [('нитка', 1), ('статья', 1), ('разумный', 1), ('жизнь', 1)], 'http://cmiruponitke.ru')
# 9 ('Купить термос, термокружку, ланчбокс и термосумку в интернет магазине | Доставка по всей России', [('термос', 1), ('термокружка', 1), ('ланчбокс', 1), ('термосумка', 1), ('россия', 1)], 'http://kupit-termos.ru')
# 10 ('binogi.ru - Всё о ногах, болезнях ног и их лечении', [('binogi', 1), ('нога', 1), ('болезнь', 2)], 'http://binogi.ru')
# 11 ('Дизайн интерьера, дизайн квартир, дома, курсы дизайна, школа дизайна АртБюро', [('дизайн', 1), ('интерьер', 4), ('дизайн', 1), ('квартира', 1), ('дом', 1), ('курс', 1), ('дизайн', 1)], 'http://artburo.su')
# 12 ('Доставка пиццы и роллов в Коломне. Заказать суши в Коломне. Заказать пиццу в Коломне. Центр Суши', [('пицца', 2), ('ролл', 2), ('заказать', 1), ('суши', 2)], 'http://center-sushi.ru')
# 13 ('Купить дешево Леджинсы Slim Jeggings с карманами комплект из 3-х цветов', [('дёшево', 1), ('леджинса', 1), ('slim', 1), ('jeggings', 1), ('карман', 1)], 'http://top-veshi.ru')
# 14 ('Скачать фильмы, музыку, игры через торрент на высокой скорости', [('фильм', 1), ('музыка', 1), ('торрент', 1), ('высокий', 1), ('скорость', 1)], 'http://torrentk.ru')
# 15 ('Фабрика "Берест" - межкомнатные двери из массива, арки, порталы, плинтуса, наличники.', [('фабрика', 1), ('берест', 1), ('межкомнатный', 1), ('дверь', 1), ('массив', 1), ('арка', 1), ('плинтус', 1), ('наличник', 1)], 'http://dveri-berest.ru')
# 16 ('Курорты Абхазии | "Центр Онлайн Бронирования"® - Отели, пансионаты, санатории Абхазии', [('курорт', 2), ('абхазия', 1), ('бронирования®', 1), ('отель', 1), ('пансионат', 1), ('санаторий', 1)], 'http://xn----8sbad5agaj0btbyj9a5f.xn--80asehdb')

# %%
embs = dict()
with open('ft_native_300_ru_wiki_lenta_lemmatize.vec', 'r', encoding='utf-8') as fasttext_embs:
    for ind, line in enumerate(fasttext_embs):
        if ind == 0:
            continue
        key, *value, _ = line.split(' ')
        embs[key] = np.asarray(value, dtype=np.float32)

# %%
final_corpus = list()
final_urls = list()
final_raws = list()

for raw_txt, record, url in corpus:
    words, tfidf_scores = zip(*record)
    best_indices = np.asarray(tfidf_scores).argsort()[-4:][::-1]
    best_words = np.asarray(words)[best_indices].tolist()
    final_corpus.append(best_words)
    final_urls.append(url)
    final_raws.append(raw_txt)

# %%
from sklearn.preprocessing import normalize

embs_corpus = list()

for record in final_corpus:
    result = np.zeros(300, dtype=np.float32)
    rec_len = len(record)
    for word in record:
        if word in embs:
            result += embs[word]        
    embs_corpus.append(result)
    
embs_corpus = normalize(np.asarray(embs_corpus)).tolist()

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
model = MiniBatchKMeans(n_clusters=256, init='k-means++',
                        max_iter=1024, batch_size=256, verbose=0, 
                        compute_labels=True, random_state=1, tol=0.0, 
                        max_no_improvement=64, n_init=32, reassignment_ratio=0.04)

# %%
model.fit(embs_corpus)
# Out:
# MiniBatchKMeans(batch_size=256, compute_labels=True, init='k-means++',
#         init_size=None, max_iter=1024, max_no_improvement=64,
#         n_clusters=256, n_init=32, random_state=1, reassignment_ratio=0.04,
#         tol=0.0, verbose=0)

# %%
model.inertia_
# Out:
# 57380.76467968023

# %%
preds = model.predict(embs_corpus)

# %%
stats = pd.DataFrame()

# %%
stats['raw_text'] = final_raws
stats['text'] = [' '.join(x) for x in final_corpus]
stats['cluster'] = preds
stats['url'] = final_urls

# %%
stats.head(100)
# Out:
#                                              raw_text  \
# 0   Сеть магазинов Форма 1998 - сувениры и подарки...
# 1             Cредство для восстановления волос AZUMI
# 2   ЛамиЛэнд - интересный магазин напольных покрытий.
# 3   Купить септик Топас в Москве - от официального...
# 4   Пополнение телефона или электронного кошелька ...
# 5   Перетяжка салона автомобиля в ателье- АвтоКомфорт
# 6   Фитолампы для растений магазин в СПб, фитоламп...
# 7   продажа автозапчастей - автозапчасти из Японии...
# 8    К миру по нитке. Статьи о разумной жизни в мире.
# 9   Купить термос, термокружку, ланчбокс и термосу...
# 10  binogi.ru - Всё о ногах, болезнях ног и их леч...
# 11  Дизайн интерьера, дизайн квартир, дома, курсы ...
# 12  Доставка пиццы и роллов в Коломне. Заказать су...
# 13  Купить дешево Леджинсы Slim Jeggings с кармана...
# 14  Скачать фильмы, музыку, игры через торрент на ...
# 15  Фабрика "Берест" - межкомнатные двери из масси...
# 16  Курорты Абхазии | "Центр Онлайн Бронирования"®...
# 17  Салон RONDO - свадебные и вечерние платья - РО...
# 18  Главная страница | 13-я ежегодная международна...
# 19  AllProject.by | Тут вы можете выбрать и купить...
# 20  Купить Арабские масляные духи и косметику в ма...
# 21  Компания Анкер - продажа металлических сеток в...
# 22  Психология: отношения, брак, любовь, измены, в...
# 23  Блог о путешествиях Darwin2.ru - Самостоятельн...
# 24  Купить керамическую плитку в Калининграде - Да...
# 25  Интертекстиль - Интернет-магазин текстильной п...
# 26                Аппарат для сварки скруток ТС 700-2
# 27  Аниме и фильмы онлайн на anime-extreme.ru 16+ ...
# 28  Stilouette Услуги стилиста онлайн в Германии /...
# 29  Чудеса вокруг Алисы - "Алиса в Стране чудес" и...
# ..                                                ...
# 70  Камелёк | "Камелёк" - печи, камины, каминные т...
# 71  «Эксперт ЮГ» деловой портал юга России, журнал...
# 72  СК Петрострой | Монолитные фундаменты и цоколь...
# 73  ООО"ФронтЭнергоСтрой" - Комплексный монтаж вен...
# 74  Амикамода — кожаные диваны из италии | кожаные...
# 75  AKAI РОССИЯ  - аудиотехника, видеотехника, быт...
# 76  МастерГрад - Электромонтаж, установка охранной...
# 77          Дневник Фостера — жЫвой легенды хакаснета
# 78  Няни и домработницы из Филиппин, англоязычный ...
# 79    Kino History - сайт исторических фильмов онлайн
# 80  Студия архитектурной трехмерной (3d) визуализа...
# 81  STALKER Зов Припяти скачать торрент бесплатно ...
# 82  Парогенераторы высокого давления - оборудовани...
# 83  Студия декора "Центр Камня" - салон-магазин ст...
# 84  Вейп-Шоп TrueVaping.ru - интернет-магазин элек...
# 85    МосКостюмер - прокат и аренда костюмов в Москве
# 86  Фонд поддержки предпринимательства и предостав...
# 87  Сайт фотостудии «Atop Studio» | услуги студийн...
# 88                 Фотографии природы и птиц Сахалина
# 89  Мтааламу - для профи и профессиональных любителей
# 90    Главная - Анекдоты: Улыбайся! Смейся! Веселись!
# 91       «АвтоКрафт» — автомобильные чехлы из экокожи
# 92  Автозапчасти оптом - продажа, купить запчасти ...
# 93           Интернет-издание о моде и стиле - Aplure
# 94  Главная - Всероссийский портал общественно-акт...
# 95  Официальный сайт Красногорский район Удмуртска...
# 96                            Russian ROTAX Kart Club
# 97  ФГУП НИИР - официальный сайт | Научно-исследов...
# 98  Русский Фейерверк. Купить пиротехнику. Заказат...
# 99  Взрослым о детях | Сайт для родителей | Все о ...
#
#                                                text  cluster  \
# 0                 назначение особый подарок сувенир      213
# 1                     волос восстановление cредство      108
# 2                     напольный интересный ламилэнд      151
# 3                  производитель дилер топас септик      207
# 4                  карта скретч кошелёк электронный      111
# 5           автокомфорт ателье автомобиль перетяжка       43
# 6                      растение фитолампа фитолампа       19
# 7                  автозапчасть япония автозапчасть      241
# 8                       жизнь разумный статья нитка      117
# 9            россия термосумка ланчбокс термокружка      138
# 10                              болезнь нога binogi       60
# 11                         интерьер дизайн курс дом       52
# 12                         суши ролл пицца заказать       20
# 13                    карман jeggings slim леджинса      254
# 14                  скорость высокий торрент музыка      139
# 15                     наличник плинтус арка массив      151
# 16                 курорт санаторий пансионат отель       32
# 17                  платье вечерний свадебный rondo      192
# 18           цод выставка конференция международный       50
# 19                    проект загородный дом коттедж       99
# 20                       обзор отзыв низкий arabica       54
# 21              петербург сетка металлический анкер      151
# 22                  вопрос важный воспитание измена      255
# 23        путешествие европа самостоятельный darwin      119
# 24                        керамик гауди дать плитка       30
# 25              продукция текстильный интертекстиль      125
# 26                           скрутка сварка аппарат       98
# 27                        extreme anime фильм аниме      113
# 28                               стилист stilouette      128
# 29                         чудо страна вокруг алиса      117
# ..                                              ...      ...
# 70                      камин каминный печь камелёк       87
# 71                             россия юг деловой юг      198
# 72                      область лена этаж цокольный       99
# 73           монтаж комплексный ооофронтэнергострой      164
# 74                    италия диван фирменный европа      105
# 75    портативный бытовой видеотехника аудиотехника      134
# 76           дом умный видеодомофон видеонаблюдение      228
# 77                                   фостер дневник       12
# 78          азумить агентство персонал англоязычный       16
# 79                  фильм исторический history kino       76
# 80     визуализация трёхмерный архитектурный студия      140
# 81              версия оригинальный торрент припять      148
# 82                паром мойка оборудование давление      126
# 83          материал отделочный строительный камень        1
# 84                  электронный truevaping шоп вейп      111
# 85                        аренда прокат москостюмер       62
# 86                  нао бизнес развитие организация       34
# 87                 студийный studio atop фотостудия      140
# 88                 сахалин птица природа фотография       41
# 89                   профессиональный профи мтаалам      211
# 90                       смеяться улыбаться анекдот      117
# 91            экокожа чехол автомобильный автокрафт      169
# 92              форум автозапчасть поставка оптовый       44
# 93                               стиль мода издание      128
# 94         школа активный общественно всероссийский       50
# 95  образование муниципальный республика удмуртский       75
# 96                          club kart rotax russian      199
# 97           институт исследовательский научно ниир      122
# 98              салют заказать пиротехник фейерверк      149
# 99                родитель ребёнок ребёнок взрослый       31
#
#                                                url
# 0                              http://forma1998.ru
# 1                             http://azumihair.com
# 2                               http://lamiland.ru
# 3                                  http://glira.ru
# 4                           http://money2mobile.ru
# 5                            http://tyuningavto.ru
# 6                               http://letsgrow.ru
# 7                                http://filtok2.ru
# 8                           http://cmiruponitke.ru
# 9                           http://kupit-termos.ru
# 10                                http://binogi.ru
# 11                               http://artburo.su
# 12                          http://center-sushi.ru
# 13                             http://top-veshi.ru
# 14                              http://torrentk.ru
# 15                          http://dveri-berest.ru
# 16  http://xn----8sbad5agaj0btbyj9a5f.xn--80asehdb
# 17                           http://salon-rondo.ru
# 18                               http://dcforum.ru
# 19                            http://allproject.by
# 20                          https://al-arabica.ru/
# 21                             http://anker-spb.ru
# 22                             http://prelative.ru
# 23                               http://darwin2.ru
# 24                              http://gaudi-39.ru
# 25                       https://intertekstile.ru/
# 26                         http://elektroprizma.ru
# 27                         http://anime-extreme.ru
# 28                           http://stilouette.com
# 29                      http://all-around-alice.ru
# ..                                             ...
# 70                               http://camelek.ru
# 71                           http://expertsouth.ru
# 72                           http://petrostroy.pro
# 73                         http://front-energo.com
# 74                             http://amikamoda.ru
# 75                                  http://akai.ru
# 76                                 http://e-pik.ru
# 77                             http://i-foster.com
# 78                           http://azumi-staff.ru
# 79                         http://kino-history.net
# 80                                http://3dmode.ru
# 81                            http://stalkerzov.ru
# 82                           http://moikaparom.com
# 83                          http://stone-center.ru
# 84                            http://truevaping.ru
# 85                           http://moskostumer.ru
# 86                                http://fond83.ru
# 87                            http://atopstudio.ru
# 88                             http://sakhscape.ru
# 89                              http://mtaalamu.ru
# 90                           http://ha-ha-ha-ha.ru
# 91                           http://avto-craft.com
# 92                      https://www.forum-nnov.ru/
# 93                               http://aplure.com
# 94                                http://oash.info
# 95                             http://mo-krasno.ru
# 96                      http://russianrotaxkart.ru
# 97                                https://niir.ru/
# 98                     http://russkij-fejerverk.ru
# 99                    http://xn--2-8sbxpv.xn--p1ai
#
# [100 rows x 4 columns]

# %%
themes = []

for i in range(stats['cluster'].max()+1):
    theme = list(stats[stats['cluster'] == i]['text'].apply(lambda x: x.split()))
    res = []
    for i in theme:
        for j in i:
            res.append(j)
    try:
        themes.append(pd.Series(res).value_counts().index[0] + ' ' + str(pd.Series(res).describe()[3] / pd.Series(res).describe()[0])[:4])
    except:
        themes.append('Undifined')
        
#print(list(zip(range(stats['cluster'].max()+1),themes)))

stats['main_theme'] = stats['cluster'].apply(lambda x: themes[x])

# %%
for key, i in enumerate(themes):
    print(key, i)
# Out:
# 0 массаж 0.15
# 1 строительный 0.22
# 2 имя 0.28
# 3 рука 0.22
# 4 часы 0.20
# 5 hugedomains 0.02
# 6 такси 0.27
# 7 женский 0.22
# 8 детский 0.27
# 9 женщина 0.19
# 10 перевозка 0.08
# 11 рабочий 0.28
# 12 играть 0.00
# 13 футбол 0.05
# 14 развитие 0.20
# 15 стол 0.18
# 16 новость 0.09
# 17 новость 0.27
# 18 материал 0.03
# 19 растение 0.08
# 20 суши 0.31
# 21 ремонт 0.26
# 22 знак 0.04
# 23 православный 0.05
# 24 цветок 0.20
# 25 оптом 0.05
# 26 оборудование 0.23
# 27 двepь 0.16
# 28 дон 0.26
# 29 город 0.12
# 30 плитка 0.27
# 31 ребёнок 0.19
# 32 отель 0.19
# 33 порно 0.23
# 34 бизнес 0.26
# 35 продвижение 0.05
# 36 дверь 0.20
# 37 жк 0.14
# 38 одежда 0.11
# 39 тур 0.27
# 40 музыка 0.06
# 41 животное 0.05
# 42 детский 0.28
# 43 тюнинг 0.20
# 44 поставка 0.20
# 45 комплекс 0.03
# 46 домашний 0.26
# 47 iphone 0.07
# 48 vk 0.25
# 49 блог 0.46
# 50 форум 0.13
# 51 финский 0.30
# 52 дизайн 0.24
# 53 брус 0.22
# 54 отзыв 0.26
# 55 рыбалка 0.15
# 56 аренда 0.31
# 57 работа 0.04
# 58 мебель 0.35
# 59 изделие 0.06
# 60 лечение 0.12
# 61 авто 0.10
# 62 прокат 0.26
# 63 шкаф 0.10
# 64 юридический 0.10
# 65 объявление 0.30
# 66 крым 0.10
# 67 оптом 0.22
# 68 недвижимость 0.20
# 69 минск 0.06
# 70 выгодный 0.25
# 71 лодка 0.04
# 72 рф 0.16
# 73 красота 0.28
# 74 куртка 0.17
# 75 муниципальный 0.14
# 76 фильм 0.15
# 77 справочник 0.27
# 78 язык 0.19
# 79 заработок 0.03
# 80 кофе 0.02
# 81 блог 0.25
# 82 петербург 0.23
# 83 event 0.24
# 84 шаблон 0.01
# 85 медицинский 0.34
# 86 автосервис 0.24
# 87 печь 0.20
# 88 питание 0.11
# 89 порно 0.22
# 90 вывоз 0.04
# 91 каталог 0.25
# 92 челябинский 0.33
# 93 журнал 0.28
# 94 россия 0.12
# 95 натяжной 0.22
# 96 книга 0.12
# 97 дом 0.18
# 98 двигатель 0.01
# 99 дом 0.24
# 100 одежда 0.09
# 101 книга 0.05
# 102 доменный 0.11
# 103 журнал 0.30
# 104 севастополь 0.25
# 105 китай 0.05
# 106 застройщик 0.14
# 107 печать 0.17
# 108 волос 0.06
# 109 секс 0.23
# 110 решение 0.35
# 111 электронный 0.24
# 112 поставка 0.23
# 113 porn 0.01
# 114 дача 0.29
# 115 компьютер 0.22
# 116 роды 0.22
# 117 жизнь 0.02
# 118 информационный 0.14
# 119 отдых 0.10
# 120 Undifined
# 121 тур 0.54
# 122 институт 0.05
# 123 лечение 0.19
# 124 область 0.20
# 125 фабрика 0.13
# 126 отопление 0.06
# 127 ювелирный 0.13
# 128 мода 0.17
# 129 анализ 0.02
# 130 ремонт 0.28
# 131 студент 0.15
# 132 детский 0.23
# 133 windows 0.14
# 134 техника 0.24
# 135 билет 0.15
# 136 кредит 0.08
# 137 район 0.05
# 138 модель 0.00
# 139 низкий 0.10
# 140 студия 0.25
# 141 сервис 0.04
# 142 театр 0.17
# 143 республика 0.16
# 144 ао 0.04
# 145 косметика 0.22
# 146 хостинг 0.18
# 147 info 0.27
# 148 игровой 0.03
# 149 праздник 0.12
# 150 телефон 0.19
# 151 забор 0.04
# 152 кдц 0.3
# 153 мебель 0.19
# 154 финансовый 0.01
# 155 туристический 0.24
# 156 авто 0.25
# 157 материал 0.25
# 158 доменный 0.25
# 159 инвалид 0.13
# 160 балкон 0.24
# 161 мастер 0.05
# 162 натуральный 0.13
# 163 картина 0.06
# 164 строительство 0.03
# 165 здоровый 0.22
# 166 шина 0.26
# 167 орёл 0.46
# 168 декор 0.07
# 169 стекло 0.04
# 170 клиника 0.11
# 171 сейф 0.22
# 172 музей 0.05
# 173 больница 0.09
# 174 chain 0.42
# 175 доска 0.27
# 176 запчасть 0.22
# 177 ноутбук 0.17
# 178 обучение 0.08
# 179 Undifined
# 180 пицца 0.28
# 181 аптека 0.10
# 182 page 0.02
# 183 техника 0.16
# 184 ресторан 0.19
# 185 адвокат 0.17
# 186 быстро 0.14
# 187 область 0.22
# 188 учебный 0.25
# 189 холдинг 0.21
# 190 рецепт 0.28
# 191 мебель 0.39
# 192 свадебный 0.32
# 193 реклама 0.15
# 194 кухня 0.31
# 195 девушка 0.07
# 196 окно 0.32
# 197 край 0.20
# 198 посёлок 0.02
# 199 su 0.00
# 200 недорого 0.11
# 201 оператор 0.04
# 202 школа 0.19
# 203 конструкция 0.25
# 204 вакансия 0.24
# 205 мебель 0.15
# 206 имя 0.25
# 207 производитель 0.10
# 208 воздушный 0.20
# 209 дилер 0.06
# 210 строительство 0.31
# 211 профессиональный 0.24
# 212 отдых 0.26
# 213 подарок 0.15
# 214 ремонт 0.26
# 215 квартира 0.27
# 216 дом 0.24
# 217 спортивный 0.09
# 218 камень 0.12
# 219 собака 0.09
# 220 газовый 0.30
# 221 фонд 0.25
# 222 сад 0.17
# 223 домен 0.31
# 224 станок 0.10
# 225 keys 0.2
# 226 светильник 0.11
# 227 порно 0.42
# 228 видеонаблюдение 0.02
# 229 недвижимость 0.25
# 230 вкусный 0.10
# 231 путёвка 0.24
# 232 ремонт 0.11
# 233 отзыв 0.2
# 234 почему 0.25
# 235 психология 0.04
# 236 виза 0.16
# 237 здоровье 0.26
# 238 тв 0.07
# 239 одежда 0.26
# 240 Undifined
# 241 запчасть 0.25
# 242 expoliceman 0.33
# 243 гбу 0.28
# 244 интерьер 0.25
# 245 фото 0.13
# 246 совет 0.26
# 247 ключ 0.25
# 248 сервис 0.04
# 249 металлочерепица 0.19
# 250 торговый 0.27
# 251 баня 0.24
# 252 песнь 0.08
# 253 автомобиль 0.07
# 254 shop 0.01
# 255 ответ 0.18

# %%
stats.loc[stats.index == 10000]
# Out:
#                                                 raw_text  \
# 10000  Качественный ремонт квартиры в Калининграде от...
#
#                             text  cluster                   url   main_theme
# 10000  работа ремонтный вид метр      214  http://otdelka-kd.ru  ремонт 0.26

# %%
stats.loc[stats.cluster == 220]
# Out:
#                                                  raw_text  \
# 8411    Газовые отопительные котлы в Екатеринбурге, га...
# 11478   Сервисный центр по ремонту газовых котлов в Но...
# 17498   Магазин отопительного и газового оборудования....
# 19582   Ремонт платы управления газового котла - Ремон...
# 26073   Интернет-магазин "Газовик" - газтехника и запа...
# 26168   Монтаж отопления, ремонт газовых колонок  и ко...
# 36930   Интернет-магазин Техносбыт Киров. Продажа газо...
# 38809   Котел -ок интернет-магазин котлов в Екатеринбу...
# 41122   Оборудование для отопления и водоснабжения | Г...
# 50583   Газовая служба Ярославль, телефон газовой служ...
# 122862                Просто котел | Все о газовых котлах
# 128686               Настенный газовый котел Ferroli Diva
# 145594  Пеллетные, газовые, твердотопливные котлы | Ур...
#
#                                                  text  cluster  \
# 8411               отопительный газовый газовый котлы      220
# 11478                        котёл зип котлов газовый      220
# 17498              колонка котёл оборудование газовый      220
# 19582                 ремонт котёл газовый управление      220
# 26073                  газтехника котлы газовый часть      220
# 26168                   котлов колонка газовый ремонт      220
# 36930             инструмент котлов газовый техносбыт      220
# 38809                         ок газовый котёл котлов      220
# 41122                   котлы газовый бытовой газовый      220
# 50583                  телефон служба газовый газовый      220
# 122862                     котлы газовый котёл просто      220
# 128686                ferroli котёл газовый настенный      220
# 145594  уралтеплосервис котлы твердотопливный газовый      220
#
#                             url    main_theme
# 8411      http://baza-kotlov.ru  газовый 0.30
# 11478       http://zip-kotel.ru  газовый 0.30
# 17498    http://kotelkolonka.ru  газовый 0.30
# 19582      http://darsklimat.ru  газовый 0.30
# 26073       http://gazovik63.ru  газовый 0.30
# 26168       http://heatproff.ru  газовый 0.30
# 36930   http://technoselling.ru  газовый 0.30
# 38809       http://kotel-ok.com  газовый 0.30
# 41122       http://thermoset.ru  газовый 0.30
# 50583          http://yarsgs.ru  газовый 0.30
# 122862    http://prostokotel.ru  газовый 0.30
# 128686      http://kotly-gaz.ru  газовый 0.30
# 145594          http://uts74.su  газовый 0.30

# %%
stats.sort_values(by='cluster').to_csv('sites_stats.csv', index=False, sep=';')

# %%
a = stats[['cluster', 'url']]

# %%
a.head()
# Out:
#    cluster                     url
# 0      213     http://forma1998.ru
# 1      108    http://azumihair.com
# 2      151      http://lamiland.ru
# 3      207         http://glira.ru
# 4      111  http://money2mobile.ru

# %%
a = a.groupby(['cluster'])['url'].apply(list)

# %%
a.head()
# Out:
# cluster
# 0    [http://smsnova.ru, http://maelewano.ru, https...
# 1    [http://stone-center.ru, https://ooosts.ru/, h...
# 2    [https://www.reg.ru/domain/shop/lot/avtolider-...
# 3    [http://fermerok.com, http://homehandmade.ru, ...
# 4    [http://xn----7sbbibna0c5aqo4e8e.xn--p1ai, htt...
# Name: url, dtype: object

# %%
a.to_csv('grouped_clusters.csv', index=True)

# %%
"""
from sklearn.metrics import silhouette_score

silhouette_score(stats['text'], stats['cluster'], metric='euclidean')
"""
# Out:
# "\nfrom sklearn.metrics import silhouette_score\n\nsilhouette_score(stats['text'], stats['cluster'], metric='euclidean')\n"
